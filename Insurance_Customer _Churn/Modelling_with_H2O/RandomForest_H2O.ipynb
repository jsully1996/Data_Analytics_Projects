# %% [markdown]
# # Random Forest Predictive Model with H2O

# %% [markdown]
# ## Step 1 : Import all Dependencies
# ### Import Pyspark and create a SparkSession, set the Sparkcontext

# %%
from pyspark.sql import SparkSession
from pyspark.sql import SparkSession, functions, types
import random
spark = SparkSession\
    .builder\
    .appName("Transform&Load")\
    .config("spark.driver.extraClassPath","/home/jim/spark-2.4.0-bin-hadoop2.7/jars/mysql-connector-java-5.1.49.jar")\
    .getOrCreate()
spark.sparkContext.setLogLevel('WARN')
sc = spark.sparkContext

# %% [markdown]
# ### View the Sparkcontext

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %% [markdown]
# ### Create an H2O cluster inside the Spark cluster

# %%
from pysparkling import *
hc = H2OContext.getOrCreate(spark)
import h2o
# Out:
# Method getOrCreate with spark argument is deprecated. Please use either just getOrCreate() or if you need to pass extra H2OConf, use getOrCreate(conf). The spark argument will be removed in release 3.32.
# Connecting to H2O server at http://172.29.157.231:54325 ... successful.
# --------------------------  -------------------------------------------------------------------------------------------------------
# H2O_cluster_uptime:         12 secs
# H2O_cluster_timezone:       America/Vancouver
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.0.4
# H2O_cluster_version_age:    6 days
# H2O_cluster_name:           sparkling-water-jim_local-1591600245615
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    789 Mb
# H2O_cluster_total_cores:    4
# H2O_cluster_allowed_cores:  4
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://172.29.157.231:54325
# H2O_connection_proxy:       null
# H2O_internal_security:      False
# H2O_API_Extensions:         XGBoost, Algos, Amazon S3, Sparkling Water REST API Extensions, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.1 final
# --------------------------  -------------------------------------------------------------------------------------------------------
# Sparkling Water Context:
#  * Sparkling Water Version: 3.30.0.4-1-2.4
#  * H2O name: sparkling-water-jim_local-1591600245615
#  * cluster size: 1
#  * list of used nodes:
#   (executorId, host, port)
#   ------------------------
#   (0,172.29.157.231,54325)
#   ------------------------
#
#   Open H2O Flow in browser: http://172.29.157.231:54327 (CMD + click in Mac OSX)

# %% [markdown]
# ## Step 2 : Get the Data
# ### Read the data saved as a mySQL database table into a spark Dataframe

# %%
spark_df = spark.read\
    .format("jdbc")\
    .option("url", "jdbc:mysql://localhost/Insurance")\
    .option("driver", "com.mysql.jdbc.Driver")\
    .option("dbtable", "Insurance_numeric").option("user", "jsully")\
    .option("password", "whatisreal1").load()
spark_df.select(spark_df.columns[:6]).show(5)
# Out:
# +-----------------------+---+-----------------+------+--------------------+---------------------+
# |Customer Lifetime Value|Age|Effective To Date|Income|Monthly Premium Auto|Total Written Premium|
# +-----------------------+---+-----------------+------+--------------------+---------------------+
# |                9996.58| 44|       18-04-2019| 39433|                 105|                33435|
# |                4009.22| 45|       12-04-2019|335099|                 127|                41317|
# |                5805.17| 27|       18-08-2020|251960|                 247|                38908|
# |                 5874.0| 35|       21-08-2020|198003|                 156|                22792|
# |                7854.84| 38|       11-11-2018|410607|                  48|                33689|
# +-----------------------+---+-----------------+------+--------------------+---------------------+
# only showing top 5 rows

# %% [markdown]
# ### Convert the Spark Df to an H2O frame and describe it

# %%
h2o_df = hc.asH2OFrame(spark_df)
print("The H2O frame has {} rows and {} columns".format(h2o_df.shape[0],h2o_df.shape[1]))
h2o_df.summary()
# Out:
# The H2O frame has 4856 rows and 33 columns
# <table>
# <thead>
# <tr><td>sigma  </td><td>2588.9688145026144       </td><td>7.436430321773121 </td><td>0.7716430259183207 </td><td>141502.9612782824 </td><td>64.68559499575768     </td><td>12928.541105040944     </td><td>2896.6062673621154</td><td>0.2881419338264036</td><td>5.766021378651545   </td><td>2880.622871183775</td><td>14.136018370278661       </td><td>27.82175833959348              </td><td>0.817653022581466          </td><td>2.876061698947571   </td><td>4.636621656235225            </td><td>2.583954168975499 </td><td>0.49977314894511604</td><td>0.8175231417287632</td><td>1.7085901741410319</td><td>1.1207487016475102       </td><td>0.5000513210070957</td><td>0.8184919392456173   </td><td>1.1147437914906977    </td><td>1.115025631796455  </td><td>1.1155744984934035   </td><td>1.117837337602026       </td><td>1.4139283470220758   </td><td>1401.950783729584         </td><td>1.993418046783163</td><td>149.13691947228054</td><td>1358.7756866175719</td><td>2.959713603438183           </td><td>0.5000290542748945</td></tr>
# <tr><td>zeros  </td><td>0                        </td><td>0                 </td><td>0                  </td><td>0                 </td><td>0                     </td><td>0                      </td><td>0                 </td><td>2                 </td><td>0                   </td><td>1                </td><td>92                       </td><td>53                             </td><td>1661                       </td><td>512                 </td><td>0                            </td><td>575               </td><td>2509               </td><td>1661              </td><td>853               </td><td>1252                     </td><td>2430              </td><td>1651                 </td><td>1243                  </td><td>1246               </td><td>1289                 </td><td>1235                    </td><td>993                  </td><td>1                         </td><td>728              </td><td>179               </td><td>11                </td><td>872                         </td><td>2405              </td></tr>
# <tr><td>missing</td><td>0                        </td><td>0                 </td><td>0                  </td><td>0                 </td><td>0                     </td><td>0                      </td><td>0                 </td><td>0                 </td><td>0                   </td><td>0                </td><td>0                        </td><td>0                              </td><td>0                          </td><td>0                   </td><td>0                            </td><td>0                 </td><td>0                  </td><td>0                 </td><td>0                 </td><td>0                        </td><td>0                 </td><td>0                    </td><td>0                     </td><td>0                  </td><td>0                    </td><td>0                       </td><td>0

# %% [markdown]
# ## Step 3 : Prepare the Dataset and feed it to a model
# ### Define the training parameters, input and target parameters.

# %%
# Input parameters that are going to train. In this case : all columns except churn
training_columns = h2o_df.columns[:-1]
# Output parameter train against input parameters
response_column = 'Churn'

# %% [markdown]
# ### Split the Data into train and Test sets
# The testing data will help you to verify the validity of your model after creating it. And it will also prevent model over fitting to the given data.

# %%
# Split data into train and testing
train, test = h2o_df.split_frame(ratios=[0.8])

# %% [markdown]
# ### Initiate the Random Forest model, define it with the required parameters and then train it.

# %%
from h2o.estimators import H2ORandomForestEstimator
#h2o.init()
# Define model
model = H2ORandomForestEstimator(ntrees=50, max_depth=20, nfolds=10)

# Train model
model.train(x=training_columns, y=response_column, training_frame=train)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%

# %% [markdown]
# ### CHeck the model's performance

# %%
performance = model.model_performance(test_data=test)
print (performance)
# Out:
# ModelMetricsRegression: drf
# ** Reported on test data. **
#
# MSE: 0.2601156888147461
# RMSE: 0.5100153809589923
# MAE: 0.5025258930220345
# RMSLE: 0.3582082739015907
# Mean Residual Deviance: 0.2601156888147461

# %% [markdown]
# #### Save the model to local file system

# %%
h2o.save_model(model=model, path="RF_Insurance_model", force=True)
# Out:
# '/home/jim/Documents/sparkling-water-3.30.0.4-1-2.4/RF_Insurance_model/DRF_model_python_1591600273347_1'

# %% [markdown]
# ### Show the model details

# %%
model
# Out:
# Model Details
# =============
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  DRF_model_python_1591600273347_1
#
#
# Model Summary:
#      number_of_trees  number_of_internal_trees  model_size_in_bytes  \
# 0               50.0                      50.0             375810.0
#
#    min_depth  max_depth  mean_depth  min_leaves  max_leaves  mean_leaves
# 0       18.0       20.0       19.86       538.0       629.0       594.06
# ModelMetricsRegression: drf
# ** Reported on train data. **
#
# MSE: 0.2639644080003918
# RMSE: 0.5137746665615109
# MAE: 0.49683306728584103
# RMSLE: 0.3594929987528265
# Mean Residual Deviance: 0.2639644080003918
#
# ModelMetricsRegression: drf
# ** Reported on cross-validation data. **
#
# MSE: 0.2540269320286576
# RMSE: 0.5040108451498416
# MAE: 0.4963127403375496
# RMSLE: 0.35363843779933546
# Mean Residual Deviance: 0.2540269320286576
#
# Cross-Validation Metrics Summary:
#                                    mean            sd    cv_1_valid  \
# 0                     mae     0.4963061  0.0044579403    0.49884567
# 1  mean_residual_deviance     0.2540221  0.0044468003    0.25660747
# 2                     mse     0.2540221  0.0044468003    0.25660747
# 3                      r2  -0.020484393   0.017332442  -0.026490971
# 4       residual_deviance     0.2540221  0.0044468003    0.25660747
# 5                    rmse     0.5039887   0.004406204     0.5065644
# 6                   rmsle    0.35355663  0.0060714753    0.35622177
#
#     cv_2_valid    cv_3_valid    cv_4_valid    cv_5_valid    cv_6_valid  \
# 0   0.49887803    0.48952442     0.4946703     0.4945817     0.4956139
# 1   0.25628483    0.24759479    0.25241446    0.25190705    0.25307295
# 2   0.25628483    0.24759479    0.25241446    0.25190705    0.25307295
# 3  -0.03650415  2.5801553E-4  -0.009878392  -0.009735626  -0.030263606
# 4   0.25628483    0.24759479    0.25241446    0.25190705    0.25307295
# 5    0.5062458    0.49758896     0.5024087     0.5019034    0.50306356
# 6   0.36238262    0.34413302      0.352373     0.3567748    0.34493846
#
#      cv_7_valid   cv_8_valid   cv_9_valid   cv_10_valid
# 0     0.5041945    0.4912182   0.49450418     0.5010299
# 1    0.26184928   0.24892348   0.25236067     0.2592059
# 2    0.26184928   0.24892348   0.25236067     0.2592059
# 3  -0.047829106  0.002726303  -0.01030276  -0.036823645
# 4    0.26184928   0.24892348   0.25236067     0.2592059
# 5    0.51171213   0.49892232    0.5023551    0.50912267
# 6    0.35786304   0.34783491   0.35528642     0.3577583
# Scoring History:
#                 timestamp    duration  number_of_trees  training_rmse  \
# 0     2020-06-08 00:44:03  12.717 sec              0.0            NaN
# 1     2020-06-08 00:44:03  12.777 sec              1.0       0.672536
# 2     2020-06-08 00:44:03  12.811 sec              2.0       0.670496
# 3     2020-06-08 00:44:03  12.839 sec              3.0       0.654237
# 4     2020-06-08 00:44:03  12.860 sec              4.0       0.636324
# 5     2020-06-08 00:44:03  12.881 sec              5.0       0.629090
# 6     2020-06-08 00:44:03  12.901 sec              6.0       0.611925
# 7     2020-06-08 00:44:03  12.921 sec              7.0       0.601446
# 8     2020-06-08 00:44:03  12.942 sec              8.0       0.592244
# 9     2020-06-08 00:44:03  12.965 sec              9.0       0.583014
# 10    2020-06-08 00:44:03  13.000 sec             10.0       0.574631
# 11    2020-06-08 00:44:03  13.033 sec             11.0       0.567541
# 12    2020-06-08 00:44:03  13.060 sec             12.0       0.561195
# 13    2020-06-08 00:44:03  13.086 sec             13.0       0.556868
# 14    2020-06-08 00:44:03  13.115 sec             14.0       0.550381
# 15    2020-06-08 00:44:03  13.146 sec             15.0       0.545839
# 16    2020-06-08 00:44:03  13.169 sec             16.0       0.542303
# 17    2020-06-08 00:44:03  13.193 sec             17.0       0.539091
# 18    2020-06-08 00:44:03  13.216 sec             18.0       0.537626
# 19    2020-06-08 00:44:03  13.239 sec             19.0       0.534273
#
#     training_mae  training_deviance
# 0            NaN                NaN
# 1       0.476249           0.452305
# 2       0.489213           0.449564
# 3       0.488699           0.428026
# 4       0.485949           0.404908
# 5       0.495190           0.395754
# 6       0.493218           0.374452
# 7       0.495600           0.361738
# 8       0.495808           0.350753
# 9       0.496234           0.339905
# 10      0.495247           0.330201
# 11      0.494946           0.322103
# 12      0.493709           0.314940
# 13      0.494486           0.310102
# 14      0.492984           0.302919
# 15      0.492870           0.297940
# 16      0.492674           0.294093
# 17      0.492135           0.290619
# 18      0.492339           0.289042
# 19      0.491009           0.285447
# See the whole table with table.as_data_frame()
#
# Variable Importances:
#                          variable  relative_importance  scaled_importance  \
# 0           Total Written Premium          1472.453613           1.000000
# 1        Total Claim Amount Index          1440.992920           0.978634
# 2                          Losses          1439.602417           0.977689
# 3                     Commissions          1420.929321           0.965008
# 4            Monthly Premium Auto          1414.790771           0.960839
# 5                          Income          1414.226562           0.960456
# 6         Customer Lifetime Value          1369.011841           0.929749
# 7                     Growth Rate          1358.496460           0.922607
# 8                   Company Index          1357.218872           0.921740
# 9                      Loss Ratio          1351.888062           0.918119
# 10  Months Since Policy Inception          1317.625854           0.894851
# 11        Months Since Last Claim          1301.869995           0.884150
# 12                      Job Index          1287.130859           0.874140
# 13    Number of previous policies          1251.034546           0.849626
# 14                            Age          1240.778320           0.842660
# 15             Number of Policies           952.644409           0.646978
# 16     Credit Card Provider Index           918.992920           0.624124
# 17                      CityIndex           917.183899           0.622895
# 18                 Feedback Index           831.337952           0.564594
# 19                Education Index           755.921997           0.513376
#
#     percentage
# 0     0.048682
# 1     0.047642
# 2     0.047596
# 3     0.046978
# 4     0.046775
# 5     0.046757
# 6     0.045262
# 7     0.044914
# 8     0.044872
# 9     0.044696
# 10    0.043563
# 11    0.043042
# 12    0.042555
# 13    0.041361
# 14    0.041022
# 15    0.031496
# 16    0.030383
# 17    0.030324
# 18    0.027485
# 19    0.024992
# See the whole table with table.as_data_frame()

# %% [markdown]
# ## Step 4 : Use the model to perform predictions on the Test Set
# ### First let us check the performance of the model using the test set

# %%
# Predict on the test set using the gbm model
predictions = model.predict(test)
predictions.show()
# Out:
# drf prediction progress: |████████████████████████████████████████████████| 100%
# <table>
# <thead>
# <tr><th style="text-align: right;">  predict</th></tr>
# </thead>
# <tbody>
# <tr><td style="text-align: right;"> 0.64    </td></tr>
# <tr><td style="text-align: right;"> 0.553864</td></tr>
# <tr><td style="text-align: right;"> 0.54    </td></tr>
# <tr><td style="text-align: right;"> 0.453333</td></tr>
# <tr><td style="text-align: right;"> 0.58    </td></tr>
# <tr><td style="text-align: right;"> 0.48    </td></tr>
# <tr><td style="text-align: right;"> 0.3832  </td></tr>
# <tr><td style="text-align: right;"> 0.52    </td></tr>
# <tr><td style="text-align: right;"> 0.511351</td></tr>
# <tr><td style="text-align: right;"> 0.523771</td></tr>
# </tbody>
# </table>

# %%
model.model_performance(test)
# Out:
# ModelMetricsRegression: drf
# ** Reported on test data. **
#
# MSE: 0.2601156888147461
# RMSE: 0.5100153809589923
# MAE: 0.5025258930220345
# RMSLE: 0.3582082739015907
# Mean Residual Deviance: 0.2601156888147461
